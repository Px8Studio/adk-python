# %% [markdown]
# ## Step 1: Configure Google Cloud Authentication
#
# For Vertex AI models, you need to authenticate with Google Cloud.

# %%
import os

# TODO(developer): Replace with your Google Cloud Project ID
project_id = "your-project-id"  # e.g., "my-dnb-project"

# Set the project for gcloud (if running locally)
# !gcloud config set project {project_id}

# Verify authentication
# !gcloud auth application-default login

# %% [markdown]
# ## Step 2: Connect to Toolbox Server
#
# Verify the Toolbox server is running and accessible.

# %%
from google.adk import Agent
from google.adk.runners import Runner
from google.adk.tools.toolbox_toolset import ToolboxToolset
from google.adk.sessions import InMemorySessionService
from google.adk.artifacts.in_memory_artifact_service import (
    InMemoryArtifactService,
)
from google.genai import types

# First, let's discover what's available on the server
import requests

TOOLBOX_URL = "http://localhost:5000"

try:
  # Get available toolsets
  response = requests.get(f"{TOOLBOX_URL}/api/toolsets")
  if response.status_code == 200:
    toolsets = response.json()
    print("Available toolsets:", list(toolsets.keys()))

  # Get available tools
  response = requests.get(f"{TOOLBOX_URL}/api/tools")
  if response.status_code == 200:
    tools = response.json()
    print("Available tools:", list(tools.keys()))
except Exception as e:
  print(f"Error discovering tools: {e}")

# Create agent with Toolbox tools using ADK's native integration
agent = Agent(
  name="dnb_toolbox_agent",
  model="gemini-2.0-flash",
  instruction="You are a helpful assistant that can access DNB APIs.",
  tools=[
    ToolboxToolset(
      server_url="http://localhost:5000",
      toolset_name="dnb_echo_tools"
    )
  ]
)

# Create services and runner
app_name = "dnb_toolbox_app"
user_id = "user1"
session_service = InMemorySessionService()
artifact_service = InMemoryArtifactService()

runner = Runner(
  app_name=app_name,
  agent=agent,
  session_service=session_service,
  artifact_service=artifact_service,
)

# Create a session (using await since it's async)
session = await session_service.create_session(
  app_name=app_name,
  user_id=user_id
)

# Create the message content using ADK types
content = types.Content(
  role='user',
  parts=[types.Part(text="What's in the DNB API?")]
)

# Run the agent with proper parameters
async for event in runner.run_async(
  user_id=user_id,
  session_id=session.id,
  new_message=content
):
  if event.content and event.content.parts:
    if text := ''.join(part.text or '' for part in event.content.parts):
      print(f'[{event.author}]: {text}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 69
#      63 content = types.Content(
#      64   role='user',
#      65   parts=[types.Part(text="What's in the DNB API?")]
#      66 )
#      68 # Run the agent with proper parameters
# ---> 69 async for event in runner.run_async(
#      70   user_id=user_id,
#      71   session_id=session.id,
#      72   new_message=content
#      73 ):
#      74   if event.content and event.content.parts:
#      75     if text := ''.join(part.text or '' for part in event.content.parts):
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\runners.py:428, in Runner.run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config)
#     421       asyncio.create_task(
#     422           _run_compaction_for_sliding_window(
#     423               self.app, session, self.session_service
#     424           )
#     425       )
#     427 async with Aclosing(_run_with_trace(new_message, invocation_id)) as agen:
# --> 428   async for event in agen:
#     429     yield event
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\runners.py:412, in Runner.run_async.<locals>._run_with_trace(new_message, invocation_id)
#     402       yield event
#     404 async with Aclosing(
#     405     self._exec_with_plugin(
#     406         invocation_context=invocation_context,
#    (...)    410     )
#     411 ) as agen:
# --> 412   async for event in agen:
#     413     yield event
#     414 # Run compaction after all events are yielded from the agent.
#     415 # (We don't compact in the middle of an invocation, we only compact at the end of an invocation.)
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\runners.py:498, in Runner._exec_with_plugin(self, invocation_context, session, execute_fn, is_live_call)
#     495 else:
#     496   # Step 2: Otherwise continue with normal execution
#     497   async with Aclosing(execute_fn(invocation_context)) as agen:
# --> 498     async for event in agen:
#     499       if not event.partial:
#     500         if self._should_append_event(event, is_live_call):
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\runners.py:401, in Runner.run_async.<locals>._run_with_trace.<locals>.execute(ctx)
#     399 async def execute(ctx: InvocationContext) -> AsyncGenerator[Event]:
#     400   async with Aclosing(ctx.agent.run_async(ctx)) as agen:
# --> 401     async for event in agen:
#     402       yield event
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\agents\base_agent.py:307, in BaseAgent.run_async(self, parent_context)
#     304       yield event
#     306 async with Aclosing(_run_with_trace()) as agen:
# --> 307   async for event in agen:
#     308     yield event
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\agents\base_agent.py:297, in BaseAgent.run_async.<locals>._run_with_trace()
#     294   return
#     296 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 297   async for event in agen:
#     298     yield event
#     300 if ctx.end_invocation:
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\agents\llm_agent.py:395, in LlmAgent._run_async_impl(self, ctx)
#     392   return
#     394 async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 395   async for event in agen:
#     396     self.__maybe_save_output_to_state(event)
#     397     yield event
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\flows\llm_flows\base_llm_flow.py:356, in BaseLlmFlow.run_async(self, invocation_context)
#     354 last_event = None
#     355 async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 356   async for event in agen:
#     357     last_event = event
#     358     yield event
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\flows\llm_flows\base_llm_flow.py:414, in BaseLlmFlow._run_one_step_async(self, invocation_context)
#     403 model_response_event = Event(
#     404     id=Event.new_id(),
#     405     invocation_id=invocation_context.invocation_id,
#     406     author=invocation_context.agent.name,
#     407     branch=invocation_context.branch,
#     408 )
#     409 async with Aclosing(
#     410     self._call_llm_async(
#     411         invocation_context, llm_request, model_response_event
#     412     )
#     413 ) as agen:
# --> 414   async for llm_response in agen:
#     415     # Postprocess after calling the LLM.
#     416     async with Aclosing(
#     417         self._postprocess_async(
#     418             invocation_context,
#    (...)    422         )
#     423     ) as agen:
#     424       async for event in agen:
#     425         # Update the mutable event id to avoid conflict
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\flows\llm_flows\base_llm_flow.py:780, in BaseLlmFlow._call_llm_async(self, invocation_context, llm_request, model_response_event)
#     777           yield llm_response
#     779 async with Aclosing(_call_llm_with_tracing()) as agen:
# --> 780   async for event in agen:
#     781     yield event
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\flows\llm_flows\base_llm_flow.py:764, in BaseLlmFlow._call_llm_async.<locals>._call_llm_with_tracing()
#     751 responses_generator = llm.generate_content_async(
#     752     llm_request,
#     753     stream=invocation_context.run_config.streaming_mode
#     754     == StreamingMode.SSE,
#     755 )
#     756 async with Aclosing(
#     757     self._run_and_handle_error(
#     758         responses_generator,
#    (...)    762     )
#     763 ) as agen:
# --> 764   async for llm_response in agen:
#     765     trace_call_llm(
#     766         invocation_context,
#     767         model_response_event.id,
#     768         llm_request,
#     769         llm_response,
#     770     )
#     771     # Runs after_model_callback if it exists.
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\flows\llm_flows\base_llm_flow.py:974, in BaseLlmFlow._run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#     972   yield error_response
#     973 else:
# --> 974   raise model_error
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\flows\llm_flows\base_llm_flow.py:958, in BaseLlmFlow._run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#     956 try:
#     957   async with Aclosing(response_generator) as agen:
# --> 958     async for response in agen:
#     959       yield response
#     960 except Exception as model_error:
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\models\google_llm.py:111, in Gemini.generate_content_async(self, llm_request, stream)
#      99 async def generate_content_async(
#     100     self, llm_request: LlmRequest, stream: bool = False
#     101 ) -> AsyncGenerator[LlmResponse, None]:
#     102   """Sends a request to the Gemini model.
#     103
#     104   Args:
#    (...)    109     LlmResponse: The model response.
#     110   """
# --> 111   await self._preprocess_request(llm_request)
#     112   self._maybe_append_user_content(llm_request)
#     114   # Handle context caching if configured
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\models\google_llm.py:294, in Gemini._preprocess_request(self, llm_request)
#     292 async def _preprocess_request(self, llm_request: LlmRequest) -> None:
# --> 294   if self._api_backend == GoogleLLMVariant.GEMINI_API:
#     295     # Using API key from Google AI Studio to call model doesn't support labels.
#     296     if llm_request.config:
#     297       llm_request.config.labels = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\models\google_llm.py:204, in Gemini._api_backend(self)
#     200 @cached_property
#     201 def _api_backend(self) -> GoogleLLMVariant:
#     202   return (
#     203       GoogleLLMVariant.VERTEX_AI
# --> 204       if self.api_client.vertexai
#     205       else GoogleLLMVariant.GEMINI_API
#     206   )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\adk\models\google_llm.py:193, in Gemini.api_client(self)
#     186 @cached_property
#     187 def api_client(self) -> Client:
#     188   """Provides the api client.
#     189
#     190   Returns:
#     191     The api client.
#     192   """
# --> 193   return Client(
#     194       http_options=types.HttpOptions(
#     195           headers=self._tracking_headers,
#     196           retry_options=self.retry_options,
#     197       )
#     198   )
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\genai\client.py:265, in Client.__init__(self, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     262   else:
#     263     http_options = HttpOptions(base_url=base_url)
# --> 265 self._api_client = self._get_api_client(
#     266     vertexai=vertexai,
#     267     api_key=api_key,
#     268     credentials=credentials,
#     269     project=project,
#     270     location=location,
#     271     debug_config=self._debug_config,
#     272     http_options=http_options,
#     273 )
#     275 self._aio = AsyncClient(self._api_client)
#     276 self._models = Models(self._api_client)
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\genai\client.py:311, in Client._get_api_client(vertexai, api_key, credentials, project, location, debug_config, http_options)
#     294 if debug_config and debug_config.client_mode in [
#     295     'record',
#     296     'replay',
#     297     'auto',
#     298 ]:
#     299   return ReplayApiClient(
#     300       mode=debug_config.client_mode,  # type: ignore[arg-type]
#     301       replay_id=debug_config.replay_id,  # type: ignore[arg-type]
#    (...)    308       http_options=http_options,
#     309   )
# --> 311 return BaseApiClient(
#     312     vertexai=vertexai,
#     313     api_key=api_key,
#     314     credentials=credentials,
#     315     project=project,
#     316     location=location,
#     317     http_options=http_options,
#     318 )
#
# File c:\Users\rjjaf\_Projects\orkhon\.venv\Lib\site-packages\google\genai\_api_client.py:670, in BaseApiClient.__init__(self, vertexai, api_key, credentials, project, location, http_options)
#     668 else:  # Implicit initialization or missing arguments.
#     669   if not self.api_key:
# --> 670     raise ValueError(
#     671         'Missing key inputs argument! To use the Google AI API,'
#     672         ' provide (`api_key`) arguments. To use the Google Cloud API,'
#     673         ' provide (`vertexai`, `project` & `location`) arguments.'
#     674     )
#     675   self._http_options.base_url = 'https://generativelanguage.googleapis.com/'
#     676   self._http_options.api_version = 'v1beta'
#
# ValueError: Missing key inputs argument! To use the Google AI API, provide (`api_key`) arguments. To use the Google Cloud API, provide (`vertexai`, `project` & `location`) arguments.
